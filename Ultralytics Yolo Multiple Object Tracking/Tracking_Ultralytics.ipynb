# %% [markdown]
# ## Multi Object Tracking with Ultralytics YOLOv8

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8n.pt')  # Load an official Detect model


# Perform tracking with the model
results = model.track(source="1.mp4", save=True)  # Tracking with default tracker (The default tracker is BoT-SORT.)
# results = model.track(source="c.jpg", save=True)
#results = model.track(source="https://youtu.be/LNwODJXcvt4", show=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/763) /content/1.mp4: 384x640 6 persons, 1 bicycle, 2 cars, 9.8ms
# video 1/1 (2/763) /content/1.mp4: 384x640 6 persons, 1 bicycle, 2 cars, 9.2ms
# video 1/1 (3/763) /content/1.mp4: 384x640 6 persons, 1 bicycle, 2 cars, 9.3ms
# video 1/1 (4/763) /content/1.mp4: 384x640 6 persons, 1 bicycle, 2 cars, 6.5ms
# video 1/1 (5/763) /content/1.mp4: 384x640 6 persons, 1 bicycle, 2 cars, 7.0ms
# ...

# %%
from ultralytics import YOLO

# Configure the tracking parameters and run the tracker
model = YOLO('yolov8n.pt')

results = model.track(source="1.mp4",conf=0.7, iou=0.5, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/763) /content/1.mp4: 384x640 5 persons, 1 bicycle, 1 car, 8.2ms
# video 1/1 (2/763) /content/1.mp4: 384x640 4 persons, 1 bicycle, 1 car, 10.4ms
# video 1/1 (3/763) /content/1.mp4: 384x640 4 persons, 1 bicycle, 1 car, 11.0ms
# video 1/1 (4/763) /content/1.mp4: 384x640 4 persons, 1 bicycle, 1 car, 8.6ms
# video 1/1 (5/763) /content/1.mp4: 384x640 4 persons, 1 bicycle, 2 cars, 8.7ms
# ...

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8n-seg.pt')  # Load an official Segment model

# Perform tracking with the model
#results = model.track(source="HeartofStoneNetflix.mp4", save=True) # Tracking with default tracker
results = model.track(source="1.mp4", save=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 78.5MB/s]
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/763) /content/1.mp4: 384x640 5 persons, 1 bicycle, 2 cars, 46.4ms
# video 1/1 (2/763) /content/1.mp4: 384x640 5 persons, 1 bicycle, 2 cars, 26.1ms
# video 1/1 (3/763) /content/1.mp4: 384x640 5 persons, 1 bicycle, 2 cars, 20.7ms
# video 1/1 (4/763) /content/1.mp4: 384x640 6 persons, 1 bicycle, 2 cars, 14.8ms
# ...

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8n-pose.pt')  # Load an official Pose model

# Perform tracking with the model
results = model.track(source="1.mp4", save=True) # Tracking with default tracker
#results = model.track(source="https://youtu.be/LNwODJXcvt4", show=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 78.0MB/s]
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/763) /content/1.mp4: 384x640 4 persons, 40.6ms
# video 1/1 (2/763) /content/1.mp4: 384x640 4 persons, 12.3ms
# video 1/1 (3/763) /content/1.mp4: 384x640 4 persons, 12.8ms
# video 1/1 (4/763) /content/1.mp4: 384x640 4 persons, 12.7ms
# video 1/1 (5/763) /content/1.mp4: 384x640 4 persons, 10.6ms
# video 1/1 (6/763) /content/1.mp4: 384x640 4 persons, 7.4ms
# ...

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('best.pt')  # Load a custom trained model

# Perform tracking with the model
results = model.track(source="1.mp4", save=True)  # Tracking with default tracker
#results = model.track(source="tejas.mp4", save=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker

# %% [markdown]
# Configuration files are here:
#
# ### https://github.com/ultralytics/ultralytics/tree/main/ultralytics/cfg/trackers
